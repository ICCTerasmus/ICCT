# %%
# Erasmus+ ICCT project (2018-1-SI01-KA203-047081)

# Hide the code completely

from IPython.display import HTML
tag = HTML('''<style>div.input{display:none;}</style>''')
display(tag)
# Out:
# <style>div.input{display:none;}</style>

# %% [markdown]
# <table>
#     <td style="width:140px; height:140px"><img src='examples/02/img/logo-ICCT.PNG'></td>
# </table>
#
# <center><h1>Interactive Course for Control Theory</h1></center><br>
#
# Welcome to the Interactive Course for Control Theory (ICCT) platform!
#
# The interactive examples are organized in four chapters: Mathematical Examples, Time-domain Examples, Frequency-domain Examples and State-space Examples.
#
# ## Table of Contents
#
# ### 1. Mathematical Examples
#
# 1.1 Complex Numbers<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 1.1.1 [Complex Numbers in Cartesian Form](examples/01/M-01_Complex_numbers_Cartesian_form.ipynb)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 1.1.2 [Complex Numbers in Polar Form](examples/01/M-02_Complex_numbers_Polar_form.ipynb)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 1.1.2 [Powers of Complex Numbers](examples/01/M-03_Power_of_a_complex_number.ipynb)<br>
# 1.2 [Derivatives of Polynomials](examples/01/M-04_Derivation_of_polynomials.ipynb)<br>
# 1.3 [Integrals of Polynomials](examples/01/M-05_Integrals_of_polynomials.ipynb)<br>
# 1.4 [Matrix Operations](examples/01/M-06_Matrix_operations.ipynb)<br>
# 1.5 [Functions and Their Graphs](examples/01/M-07_Functions_graphs.ipynb)<br>
# 1.6 [Fast-Fourier Transform (FFT)](examples/01/M-08_Fast_Fourier_transform.ipynb)<br>
# 1.7 [Laplace Transform](examples/01/M-09_Laplace_transform.ipynb)<br>
#
# ### 2. Time-domain Examples
#
# 2.1 [Water Level Control System](examples/02/TD-01-Water-level-control-system.ipynb)<br>
# 2.2 [Antenna Azimuth Position Control System](examples/02/TD-02-Antenna-azimuth-position-control-system.ipynb)<br>
# 2.3 [Mechanical Systems](examples/02/TD-03-Mechanical-systems.ipynb)<br>
# 2.4 [Differential Equations](examples/02/TD-04-Differential-equations.ipynb)<br>
# 2.5 Linearization
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 2.5.1 [Linearization of a Function](examples/02/TD-05-Linearization-Functions.ipynb)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 2.5.2 [Linearization of a Simple Pendulum](examples/02/TD-06-Linearization-Pendulum.ipynb)<br>
# 2.6 [Poles, Zeros - Basics](examples/02/TD-07-Poles-zeros-and-system-response.ipynb)<br>
# 2.7 [Pole/Zero Placement](examples/02/TD-08-Pole-zero-placement.ipynb)<br>
# 2.8 [Partial Fraction Decomposition](examples/02/TD-09-Partial-fraction-decomposition.ipynb)<br>
# 2.9 [First- and Second-Order Systems - Basics](examples/02/TD-10-First-and-second-order-systems-Basics.ipynb)<br>
# 2.10 [Time Response of the First-Order Systems](examples/02/TD-11-Time-response-First-order-system.ipynb)<br>
# 2.11 [Dominant Pole Approximation](examples/02/TD-12-Dominant-pole-approximation.ipynb)<br>
# 2.12 [Loading Problem](examples/02/TD-13-Loading-problem.ipynb)<br>
# 2.13 [Routh and Hurwitz Stability Criterion](examples/02/TD-14-Routh-Hurwitz-stability-criterion.ipynb)<br>
# 2.14 PID Controller<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 2.14.1 [Time Response](examples/02/TD-15-PID-controller-Time-response.ipynb)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 2.14.2 [Closed-Loop System](examples/02/TD-16-PID-controller-Closed-loop-model.ipynb)<br>
# 2.15 [Steady-state Error](examples/02/TD-17-Steady-state-error.ipynb)<br>
# 2.16 [Root Locus](examples/02/TD-18-Root-locus.ipynb)<br>
#
# ### 3. Frequency-domain Examples
#
# 3.1 [Transfer Functions](examples/03/FD-01_Transfer_Functions.ipynb)<br>
# 3.2 [Bode Diagram](examples/03/FD-02_Bode_Diagram_Formulation.ipynb)<br>
# 3.3 [Nyquist Diagram](examples/03/FD-03_Nyquist_Diagram_Formulation.ipynb)<br>
# 3.4 [Negative Feedback systems](examples/03/FD-04_Negative_Feedback_Systems.ipynb)<br>
# 3.5 [Gain and Phase Margin](examples/03/FD-05_Gain_and_Phase_Margin.ipynb)<br>
# 3.6 PID Controller - Basics<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 3.6.1 [Tuning a PID controller](examples/03/FD-06_PID_Controller_Formulation.ipynb)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 3.6.2 [PID Control of First-Order Systems](examples/03/FD-07_PID_Control_of_First-Order_Systems.ipynb)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 3.6.3 [PID Control of First-Order Systems with Integrator](examples/03/FD-08_PID_Control_of_First-Order_Systems_with_Integrator.ipynb)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 3.6.4 [Control of First-Order Systems with Time Delay](examples/03/FD-09_PID_Control_of_First-Order_Systems_with_Time_Delay.ipynb)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 3.6.5 [PID Control of Second-Order Undamped and Critically Damped Systems](examples/03/FD-10_PID_Control_of_Second-Order_Undamped_and_Critically_Damped_Systems.ipynb)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 3.6.6 [PID Control of Second-Order Underdamped Systems](examples/03/FD-11_PID_Control_of_Second-Order_Underdamped_Systems.ipynb)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 3.6.7 [PID Control of Second-Order Overdamped Systems](examples/03/FD-12_PID_Control_of_Second-Order_Overdamped_Systems.ipynb)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 3.6.8 [PID Disturbance Rejection](examples/03/FD-13_PID_Disturbance_Rejection.ipynb)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 3.6.9 [Discrete PID Control of Continuous First-Order Systems](examples/03/FD-14_Discrete_PID_Control_of_Continuous_First-Order_Systems.ipynb)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 3.6.10 [Discrete PID Control of Continuous Second-Order Systems](examples/03/FD-15_Discrete_PID_Control_of_Continuous_Second-Order_Systems.ipynb)<br>
# 3.7 PID Controller Design<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 3.7.1 [Operational Amplifier – P Controller](examples/03/FD-16_OpAmp_P_Controller.ipynb)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 3.7.2 [Operational Amplifier – PI Controller](examples/03/FD-17_OpAmp_PI_Controller.ipynb)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 3.7.3 [Operational Amplifier – PD Controller](examples/03/FD-18_OpAmp_PD_Controller.ipynb)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 3.7.4 [Operational Amplifier – PID Controller](examples/03/FD-19_OpAmp_PID_Controller.ipynb)<br>
# 3.8 Real-world Systems<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 3.8.1 [Mass-Spring-Damper](examples/03/FD-20_1DoF_Mass-spring-damper.ipynb)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 3.8.2 [Ball and Beam](examples/03/FD-21_Ball_and_Beam.ipynb)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 3.8.3 [DC Motor](examples/03/FD-22_DC_Cascade.ipynb)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 3.8.4 [Ballscrew Positioner](examples/03/FD-23_DC_Ballscrew_Positioner.ipynb)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 3.8.5 [Pendulum on a Cart](examples/03/FD-24_Pendulum_on_a_Cart.ipynb)<br>
#
# ### 4. State-space Examples
#
# 4.1 [Solution of Differential Equations in Matrix Form](examples/04/SS-01-Solution_of_differential_equations_in_matrix_form.ipynb)<br>
# 4.2 [Modal Analysis](examples/04/SS-02-Modal_Analysis.ipynb)<br>
# 4.3 Diagonal Matrices<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 4.3.1 [Convergent Modes Only](examples/04/SS-03-Diagonal_matrices_only_convergent_modes.ipynb)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 4.3.2 [Divergent Modes](examples/04/SS-04-Diagonal_matrices_divergent_modes.ipynb)<br>
# 4.4 Jordan Form<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 4.4.1 [Jordan Form with Real Eigenvalues](examples/04/SS-05-Jordan_form_with_real_eigenvalues.ipynb)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 4.4.2 [Jordan Form with Complex Eigenvalues](examples/04/SS-06-Jordan_form_with_complex_eigenvalues.ipynb)<br>
# 4.5 [Transition From Differential Equation to State Space Form](examples/04/SS-07-From_differential_equation_form_to_state_space.ipynb)<br>
# 4.6 [Modal Analysis of the Mass-Spring-Damper System](examples/04/SS-08-Modal_analysis_of_the_Mass-Spring-Damper_system.ipynb)<br>
# 4.7 [Car Speed Dynamics](examples/04/SS-09-Car_speed_dynamics.ipynb)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 4.7.1 [Modal Analysis of Car Speed Dynamics](examples/04/SS-10-Modal_analysis_of_car_speed_dynamics.ipynb)<br>
# 4.8 [Lunar Lander Lateral Position Dynamics](examples/04/SS-11-Lunar_lander_lateral_position_dynamics.ipynb)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 4.8.1 [Modal Analysis of Lunar Lander](examples/04/SS-12-Modal_analysis_of_the_lunar_lander.ipynb)<br>
# 4.9 [Equilibrium Points](examples/04/SS-13-Equilibrium_points.ipynb)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 4.9.1 [Example 1](examples/04/SS-14-Equilibrium_points_example_1.ipynb)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 4.9.2 [Example 2](examples/04/SS-15-Equilibrium_points_example_2.ipynb)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 4.9.3 [Example 3](examples/04/SS-16-Equilibrium_points_example_3.ipynb)<br>
# 4.10 [Internal Stability](examples/04/SS-17-Internal_stability.ipynb)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 4.10.1 [Example 1](examples/04/SS-18-Internal_stability_example_1.ipynb)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 4.10.2 [Example 2](examples/04/SS-19-Internal_stability_example_2.ipynb)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 4.10.3 [Example 3](examples/04/SS-20-Internal_stability_example_3.ipynb)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 4.10.4 [Example 4](examples/04/SS-21-Internal_stability_example_4.ipynb)<br>
# 4.11 [Observability](examples/04/SS-22-Observability.ipynb)<br>
# 4.12 [Controllability](examples/04/SS-23-Controllability.ipynb)<br>
# 4.13 [State Space Formulation and Transfer Function](examples/04/SS-24-State_Space_Formulation_and_Transfer_Function.ipynb)<br>
# 4.14 [Internal and External Stability](examples/04/SS-25-Internal_and_external_stability.ipynb)<br>
# 4.15 [Asymptotic Observer](examples/04/SS-26-Asymptotic_observer.ipynb)<br>
# 4.16 [Luenberger Observer with Dynamic Requirements](examples/04/SS-27-Luenberger_observer_with_dynamic_requirements.ipynb)<br>
# 4.17 [Observer for the Mass-Spring-Damper System](examples/04/SS-28-Observer_for_the_mass-spring-damper_system.ipynb)<br>
# 4.18 [Observer for Unobservable Plants](examples/04/SS-29-Observer_for_unobservable_plants.ipynb)<br>
# 4.19 [State Feedback Control](examples/04/SS-30-State_feedback_control.ipynb)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 4.19.1 [State Feedback Control - Performance](examples/04/SS-31-State_feedback_control_performance.ipynb)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 4.19.2 [State Feedback Control - Tracking Specifications](examples/04/SS-32-State_feedback_control-tracking_specifications.ipynb)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 4.19.3 [State Feedback Control for Mass-Spring-Damper System](examples/04/SS-33_State_feedback_control_for_the_mass-spring-damper_system.ipynb)<br>
# 4.20 [Regulator Design](examples/04/SS-34-Regulator_design.ipynb)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 4.20.1 [Regulator for Mass-Spring-Damper System](examples/04/SS-35-Regulator_for_the_mass-spring-damper_system.ipynb)<br>
# 4.21 Real-world Examples<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 4.21.1 [Satellite Orbit Control](examples/04/SS-36-Satellite_orbit_control.ipynb)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 4.21.2 [Quadrotor Longitudinal Velocity Control](examples/04/SS-37-Quadrotor_longitudinal_velocity_control.ipynb)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 4.21.3 [Lunar Lander Horizontal Position Control](examples/04/SS-38-Lunar_lander_horizontal_position_control.ipynb)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 4.21.4 [Crane Load Position Control](examples/04/SS-39-Crane_load_position_control.ipynb)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 4.21.5 [Robotic Arm with Flexible Joint Control](examples/04/SS-40-Control_of_robotic_arm_with_flexible_joint.ipynb)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 4.21.6 [Rotary Actuator Position Control](examples/04/SS-41-Rotary_actuator_position_control.ipynb)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 4.21.7 [Missile Attitude Control](examples/04/SS-42-Missile_attitude_control.ipynb)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 4.21.8 [Hard Disk Head Control](examples/04/SS-43-Hard_Disk_head_control.ipynb)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 4.21.9 [Car Cruise Control](examples/04/SS-44-Car_cruise_control.ipynb)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 4.21.10 [Aircraft Taxi Trajectory Control](examples/04/SS-45-Aircraft_taxi_trajectory_control.ipynb)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 4.21.11 [Quadrotor Lateral Position Control](examples/04/SS-46-Quadrotor_lateral_position_control.ipynb)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 4.21.12 [Pneumatic Position Control](examples/04/SS-47-Pneumatic_position_control.ipynb)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 4.21.13 [Autonomous Underwater Vehicle (AUV) Velocity Control](examples/04/SS-48-AUV_surge_velocity_control.ipynb)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 4.21.14 [Autonomous Underwater Vehicle (AUV) Heading Control](examples/04/SS-49-AUV_heading_control.ipynb)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 4.21.15 [Autonomous Underwater Vehicle (AUV) Depth Control](examples/04/SS-50-AUV_depth_control.ipynb)<br>
#
# <br>
# <div align="center">Read more about the ICCT project on our <a href="https://icct.cafre.unipi.it/">website.</a></div>
#
#
# <!-- ## FAQ
#
# ### Can I use the developed Jupyter notebooks for my school project? -->
#
# <table>
#        <td style="width:250px; height:51px"><img src='examples/02/img/logo-EU.jpg'></td>
# </table>
